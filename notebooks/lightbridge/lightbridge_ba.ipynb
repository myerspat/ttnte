# %% [markdown]
# # 4-Lobe Lightbridge Fuel
#
# ## Burnable Absorber Displacer

# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import torch as tn
from igakit import cad

from ttnte.xs.benchmarks import kaist
from ttnte.cad.curves import qtrlobe
from ttnte.iga import IGAMesh
from ttnte.assemblers import MatrixAssembler, TTAssembler
from ttnte.linalg import LinearOperator, eig

tn.set_default_dtype(tn.float64)

# %%
# Discretization
num_ordinates = 1024

# Get XS data
xs_server = kaist()

# %%
D = 1.26 # Fuel width
D2 = D*0.5
X = 1.36 # Channel pitch
delta = 0.306 # Width of lobes
y2 = delta * 0.5
d = 0.04 # Thickness of cladding at valleys
dmax = 0.102 # Thickness of cladding at ends of the lobes
R = 0.297 # Radius defining outer curve of valleys
a = 0.156 # Displacer width

y1 = y2-d # Half of width of inner lobe
x1 = (D2 - R - y2 - dmax) # Portrusion of innerlobe
x2 = x1 + dmax # Portrusion of outer lobe

# %%
# NURBS curves
origin = cad.line(p0=(0, 0), p1=(0, 0))
burn = cad.line(p1=(a / (2 ** 0.5), 0), p0=(0, a / (2 ** 0.5)))
fuel = qtrlobe(outrad=R + d, portrs=x1, hfwidth=y1 )
clad = qtrlobe(outrad=R, portrs=x2, hfwidth=y2 )
topedge = cad.line(p0=(0, X / 2), p1=(X / 2, X / 2))
corner = cad.line(p1=(X / 2, X / 2), p0=(X / 2, X / 2))
rightedge = cad.line(p1=(X / 2, 0), p0=(X / 2, X / 2))

# %%
# NURBS patches
patches = {}
sections = [0, 1/3, 2/3, 1]
edges = [topedge, corner, rightedge]

for i in range(len(sections) - 1):
    # Line sections
    osec = origin.slice(0, sections[i], sections[i + 1])
    bsec = burn.slice(0, sections[i], sections[i + 1])
    fsec = fuel.slice(0, sections[i], sections[i + 1])
    csec = clad.slice(0, sections[i], sections[i + 1])

    # Create patches
    patches[cad.ruled(osec, bsec)] = "BA (UO2 FA)"
    patches[cad.ruled(bsec, fsec)] = "UO2 3%"
    patches[cad.ruled(fsec, csec)] = "Guide Tube"
    patches[cad.ruled(csec, edges[i])] = "Water"

# %%
# Create IGA mesh object
mesh = IGAMesh(patches)

# Refine mesh
for p in range(mesh.num_patches):
    mesh.refine(p, 6, 2)
    
# Finalize mesh
mesh.connect()

# Set reflective boundary conditions
mesh.set_reflective_condition(("left", "bottom", "top", "right"))

# Finalize mesh
mesh.finalize()

# %%
# Plot final mesh
ax = mesh.plot(num_nodes=128, plot_ctrlpts=False)
plt.legend(loc="upper center", ncol=2)
plt.tight_layout()
plt.savefig("./figs/four_lobe_ba.png", dpi=300)
plt.show()

# %%
print("Assemble system in COOrdinate format")
assembler = MatrixAssembler(
    mesh=mesh,
    xs_server=xs_server,
    num_ordinates=num_ordinates,
)
H_m, S_m, F_m, B_in_m, B_out_m = assembler.build()

# Create operators in TT format
print("\nAssemble system in TT format")
assembler = TTAssembler(
    mesh=mesh,
    xs_server=xs_server,
    num_ordinates=num_ordinates,
)
assembler.interp_jacobian = False
assembler.interp_jacobian_det = False
assembler.interp_boundary_jacobian_det = False
H_tt, S_tt, F_tt, B_in_tt, B_out_tt = assembler.build(use_tt=True, eps=1e-10)

# Save TT information
assembler.save_tt_info("./tt_info_ba.csv")
# Out:
# Assemble system in COOrdinate format
# Discretization: N = 64, G = 7, P = 12, A = 5, B = 5
# Assembling Patch 1
# Step            Shape                     Compression  Elapsed Time (s)
# H               134400,134400               37229.92        0.24
# S               2,2100,2100                   169.67        0.24
# F               2100,2100                     193.91        0.24
# B_in            134400,134400              471578.95        0.33
# B_out           134400,134400              479197.77        0.40
# Assembling Patch 2
# Step            Shape                     Compression  Elapsed Time (s)
# H               134400,134400               37229.92        0.63
# S               2,2100,2100                   169.67        0.64
# F               2100,2100                     193.91        0.64
# B_in            134400,134400              335214.34        0.73
# B_out           134400,134400              346001.61        0.79
# Assembling Patch 3
# Step            Shape                     Compression  Elapsed Time (s)
# H               134400,134400               37229.92        1.04
# S               2,2100,2100                   190.88        1.04
# F               2100,2100                        inf        1.04
# B_in            134400,134400              319643.26        1.13
# B_out           134400,134400              328556.15        1.20
# Assembling Patch 4
# Step            Shape                     Compression  Elapsed Time (s)
# H               134400,134400               37229.92        1.45
# S               2,2100,2100                   129.96        1.45
# F               2100,2100                        inf        1.45
# B_in            134400,134400              336394.21        1.56
# B_out           134400,134400              344201.68        1.63
# Assembling Patch 5
# Step            Shape                     Compression  Elapsed Time (s)
# H               134400,134400               37229.92        1.88
# S               2,2100,2100                   169.67        1.89
# F               2100,2100                     193.91        1.89
# B_in            134400,134400              471578.95        1.96
# B_out           134400,134400              478398.22        2.03
# Assembling Patch 6
# Step            Shape                     Compression  Elapsed Time (s)
# H               134400,134400               37229.92        2.29
# S               2,2100,2100                   169.67        2.30
# F               2100,2100                     193.91        2.30
# B_in            134400,134400              335214.34        2.37
# B_out           134400,134400              342966.51        2.44
# Assembling Patch 7
# Step            Shape                     Compression  Elapsed Time (s)
# H               134400,134400               37229.92        2.73
# S               2,2100,2100                   190.88        2.73
# F               2100,2100                        inf        2.73
# B_in            134400,134400              318577.78        2.81
# B_out           134400,134400              327555.22        2.88
# Assembling Patch 8
# Step            Shape                     Compression  Elapsed Time (s)
# H               134400,134400               37229.92        3.17
# S               2,2100,2100                   129.96        3.17
# F               2100,2100                        inf        3.17
# B_in            134400,134400              439305.41        3.25
# B_out           134400,134400              448935.28        3.31
# Assembling Patch 9
# Step            Shape                     Compression  Elapsed Time (s)
# H               134400,134400               37229.92        3.60
# S               2,2100,2100                   169.67        3.61
# F               2100,2100                     193.91        3.61
# B_in            134400,134400              471578.95        3.70
# B_out           134400,134400              478132.30        3.77
# Assembling Patch 10
# Step            Shape                     Compression  Elapsed Time (s)
# H               134400,134400               37229.92        4.07
# S               2,2100,2100                   169.67        4.07
# F               2100,2100                     193.91        4.07
# B_in            134400,134400              337053.29        4.17
# B_out           134400,134400              347820.46        4.24
# Assembling Patch 11
# Step            Shape                     Compression  Elapsed Time (s)
# H               134400,134400               37229.92        4.56
# S               2,2100,2100                   190.88        4.56
# F               2100,2100                        inf        4.57
# B_in            134400,134400              320835.51        4.66
# B_out           134400,134400              329942.46        4.73
# Assembling Patch 12
# Step            Shape                     Compression  Elapsed Time (s)
# H               134400,134400               37229.92        5.05
# S               2,2100,2100                   129.96        5.05
# F               2100,2100                        inf        5.05
# B_in            134400,134400              335868.80        5.16
# B_out           134400,134400              343514.38        5.23
#
# Final Operators
# H               134400,134400                3102.49        5.31
# S               2,2100,2100                    13.48        5.31
# F               2100,2100                      32.32        5.31
# B_in            134400,134400               30390.05        5.31
# B_out           134400,134400               31132.51        5.31
#
# Assemble system in TT format
# Discretization: N = 64, G = 7, P = 12, A = 5, B = 5
# Assembling Patch 1
# Step            Ranks                     Compression  Elapsed Time (s)
# J               2,6,3,3,3,3                    15.43        0.10
# J_det           1,2,1                           4.50        0.18
# R               3,9,9,9,3                       1.09        0.22
# dR              3,8,12,12,5,2                   1.44        0.22
# J_detRT         3,9,9,9,3                       1.09        0.26
# JdR             3,9,15,14,6,2                   1.03        0.27
# Intg_int        1                              12.50        0.44
# Intg_str        3,2                             5.46        0.44
# H               3,3,3,3,3,7                  3518.32        0.44
# S               3,3,2,1,1,1               3360000.00        0.44
# F               1,1,1,1,1,1               9467169.81        0.44
# Jx_det_in       1,1                             2.25        0.53
# Jy_det_in       1,1                             2.25        0.53
# Rx_in           1,3,3,1                         3.24        0.53
# Ry_in           2,6,6,3                         0.77        0.53
# Ox_in           4,5,2,1,1                       7.89        0.53
# Oy_in           4,5,2,1,1                       7.89        0.53
# ORx_in          3,4,1,1,3,3,1                  82.29        0.54
# ORy_in          4,5,2,2,6,6,3                  29.54        0.54
# ORJx_det_in     3,4,1,1,3,3,1                  82.29        0.55
# ORJy_det_in     4,5,2,2,6,6,3                  29.54        0.55
# Intg_bound_in   3,7,7,3,2                   18461.54        0.76
# H_bound_in      5,6,3,3,3,2                511072.88        0.76
# B_in            5,6,3,3,3,2               6485946.14        0.76
# Jx_det_out      1,1                             2.25        0.77
# Jy_det_out      1,1                             2.25        0.77
# Rx_out          2,6,6,2                         0.85        0.78
# Ry_out          2,6,6,3                         0.77        0.78
# Ox_out          4,5,2,1,1                       7.89        0.84
# Oy_out          4,5,2,1,1                       7.89        0.84
# ORx_out         3,4,1,2,6,6,2                  38.98        0.85
# ORy_out         4,5,2,2,6,6,3                  29.54        0.85
# ORJx_det_out    3,4,1,2,6,6,2                  38.98        0.87
# ORJy_det_out    4,5,2,2,6,6,3                  29.54        0.87
# Intg_bound_out  4,6,3,2                       104.17        1.05
# H_bound_out     4,6,3,3,3,2                  6054.05        1.05
# B_out           4,6,3,3,3,2                  6054.05        1.05
# Assembling Patch 2
# Step            Ranks                     Compression  Elapsed Time (s)
# J               3,9,12,4,4,4                    4.35        1.14
# J_det           3,9,3                           0.45        1.23
# R               3,9,23,9,3                      0.51        1.26
# dR              3,9,27,16,6,2                   0.60        1.26
# J_detRT         3,9,27,9,3                      0.45        1.27
# JdR             3,9,27,16,6,2                   0.60        1.28
# Intg_int        17                              0.74        1.53
# Intg_str        19,2                            0.87        1.53
# H               3,3,3,3,3,55                  583.84        1.53
# S               3,3,2,1,1,17              1206153.85        1.53
# F               1,1,1,1,1,17              1569635.04        1.53
# Jx_det_in       2,3                             0.58        1.62
# Jy_det_in       1,1                             2.25        1.62
# Rx_in           2,6,6,2                         0.85        1.62
# Ry_in           2,6,6,3                         0.77        1.62
# Ox_in           4,5,2,1,1                       7.89        1.62
# Oy_in           4,5,2,1,1                       7.89        1.62
# ORx_in          4,16,10,18,18,6,2               3.97        1.63
# ORy_in          4,5,2,2,6,6,3                  29.54        1.63
# ORJx_det_in     4,16,10,18,18,6,2               3.97        1.65
# ORJy_det_in     4,5,2,2,6,6,3                  29.54        1.65
# Intg_bound_in   4,10,13,12,3                 6908.55        1.91
# H_bound_in      5,10,12,12,12,3             38234.84        1.91
# B_in            5,10,12,12,12,3            572222.89        1.91
# Jx_det_out      2,3                             0.58        1.92
# Jy_det_out      1,1                             2.25        1.92
# Rx_out          2,6,6,2                         0.85        1.94
# Ry_out          2,6,6,3                         0.77        1.94
# Ox_out          4,5,2,1,1                       7.89        1.99
# Oy_out          4,5,2,1,1                       7.89        1.99
# ORx_out         4,16,10,18,18,6,2               3.97        2.01
# ORy_out         4,5,2,2,6,6,3                  29.54        2.01
# ORJx_det_out    4,16,10,18,18,6,2               3.97        2.03
# ORJy_det_out    4,5,2,2,6,6,3                  29.54        2.03
# Intg_bound_out  4,9,12,3                       25.53        2.26
# H_bound_out     4,9,12,12,12,3                780.85        2.27
# B_out           4,9,12,12,12,3                780.85        2.27
# Assembling Patch 3
# Step            Ranks                     Compression  Elapsed Time (s)
# J               3,9,12,4,4,4                    4.35        2.36
# J_det           3,6,3                           0.64        2.44
# R               3,9,9,9,3                       1.09        2.47
# dR              3,9,15,12,5,2                   1.17        2.47
# J_detRT         3,9,18,9,3                      0.63        2.48
# JdR             3,9,27,16,6,2                   0.60        2.49
# Intg_int        2                               6.25        2.67
# Intg_str        4,2                             4.11        2.67
# H               3,3,3,3,3,10                 2677.29        2.67
# S               3,3,2,1,1,2               3022650.60        2.68
# F               1,1,1,1,1,1               9467169.81        2.68
# Jx_det_in       2,3                             0.58        2.76
# Jy_det_in       1,1                             2.25        2.76
# Rx_in           2,6,6,2                         0.85        2.76
# Ry_in           2,6,6,3                         0.77        2.76
# Ox_in           2,2,2,1,1                      23.04        2.76
# Oy_in           2,2,2,1,1                      23.04        2.76
# ORx_in          4,16,18,18,18,6,2               3.04        2.78
# ORy_in          2,2,2,2,6,6,3                  40.66        2.78
# ORJx_det_in     4,16,18,18,18,6,2               3.04        2.79
# ORJy_det_in     2,2,2,2,6,6,3                  40.66        2.79
# Intg_bound_in   4,8,14,20,3                  5445.52        3.12
# H_bound_in      5,9,20,20,20,3              14155.35        3.12
# B_in            5,9,20,20,20,3             219069.31        3.12
# Jx_det_out      2,3                             0.58        3.13
# Jy_det_out      1,1                             2.25        3.13
# Rx_out          2,6,6,2                         0.85        3.15
# Ry_out          2,6,6,3                         0.77        3.15
# Ox_out          2,2,2,1,1                      23.04        3.20
# Oy_out          2,2,2,1,1                      23.04        3.20
# ORx_out         4,16,18,18,18,6,2               3.04        3.22
# ORy_out         2,2,2,2,6,6,3                  40.66        3.22
# ORJx_det_out    4,16,18,18,18,6,2               3.04        3.24
# ORJy_det_out    2,2,2,2,6,6,3                  40.66        3.24
# Intg_bound_out  4,8,19,3                       17.76        3.55
# H_bound_out     4,8,19,19,19,3                368.78        3.56
# B_out           4,8,19,19,19,3                368.78        3.56
# Assembling Patch 4
# Step            Ranks                     Compression  Elapsed Time (s)
# J               3,9,12,4,4,4                    4.35        3.65
# J_det           3,9,3                           0.45        3.73
# R               3,9,23,9,3                      0.51        3.76
# dR              3,9,27,16,6,2                   0.60        3.76
# J_detRT         3,9,27,9,3                      0.45        3.77
# JdR             3,9,27,16,6,2                   0.60        3.78
# Intg_int        16                              0.78        4.03
# Intg_str        19,2                            0.87        4.03
# H               3,3,3,3,3,54                  594.16        4.03
# S               3,3,2,1,1,16              1256494.16        4.04
# F               1,1,1,1,1,1               9467169.81        4.04
# Jx_det_in       2,3                             0.58        4.12
# Jy_det_in       1,1                             2.25        4.12
# Rx_in           2,6,6,2                         0.85        4.12
# Ry_in           2,6,6,3                         0.77        4.12
# Ox_in           4,5,2,1,1                       7.89        4.12
# Oy_in           4,5,2,1,1                       7.89        4.12
# ORx_in          4,13,10,18,18,6,2               4.25        4.14
# ORy_in          4,5,2,2,6,6,3                  29.54        4.14
# ORJx_det_in     4,13,10,18,18,6,2               4.25        4.15
# ORJy_det_in     4,5,2,2,6,6,3                  29.54        4.15
# Intg_bound_in   3,8,12,12,3                  8375.14        4.44
# H_bound_in      6,11,12,12,12,3             38069.80        4.45
# B_in            6,11,12,12,12,3            563933.69        4.45
# Jx_det_out      2,3                             0.58        4.46
# Jy_det_out      1,1                             2.25        4.46
# Rx_out          2,6,6,2                         0.85        4.47
# Ry_out          2,6,6,3                         0.77        4.47
# Ox_out          4,5,2,1,1                       7.89        4.53
# Oy_out          4,5,2,1,1                       7.89        4.53
# ORx_out         4,13,10,18,18,6,2               4.25        4.54
# ORy_out         4,5,2,2,6,6,3                  29.54        4.54
# ORJx_det_out    4,13,10,18,18,6,2               4.25        4.56
# ORJy_det_out    4,5,2,2,6,6,3                  29.54        4.56
# Intg_bound_out  4,10,12,3                      24.52        4.80
# H_bound_out     4,10,12,12,12,3               769.41        4.81
# B_out           4,10,12,12,12,3               769.41        4.81
# Assembling Patch 5
# Step            Ranks                     Compression  Elapsed Time (s)
# J               2,6,3,3,3,3                    15.43        4.90
# J_det           1,2,1                           4.50        4.98
# R               3,9,9,9,3                       1.09        5.01
# dR              3,8,12,12,5,2                   1.44        5.01
# J_detRT         3,9,9,9,3                       1.09        5.02
# JdR             3,9,15,14,6,2                   1.03        5.03
# Intg_int        1                              12.50        5.19
# Intg_str        3,2                             5.46        5.19
# H               3,3,3,3,3,7                  3518.32        5.19
# S               3,3,2,1,1,1               3360000.00        5.20
# F               1,1,1,1,1,1               9467169.81        5.20
# Jx_det_in       1,1                             2.25        5.28
# Jy_det_in       1,1                             2.25        5.28
# Rx_in           1,3,3,1                         3.24        5.28
# Ry_in           2,6,6,3                         0.77        5.28
# Ox_in           4,8,2,1,1                       5.28        5.28
# Oy_in           4,8,2,1,1                       5.28        5.28
# ORx_in          3,4,1,1,3,3,1                  82.29        5.29
# ORy_in          4,8,2,2,6,6,3                  24.51        5.29
# ORJx_det_in     3,4,1,1,3,3,1                  82.29        5.30
# ORJy_det_in     4,8,2,2,6,6,3                  24.51        5.30
# Intg_bound_in   3,9,10,3,2                  14922.28        5.48
# H_bound_in      4,9,3,3,3,2                501091.88        5.49
# B_in            4,9,3,3,3,2               6003110.67        5.49
# Jx_det_out      1,1                             2.25        5.50
# Jy_det_out      1,1                             2.25        5.50
# Rx_out          2,6,6,2                         0.85        5.51
# Ry_out          2,6,6,3                         0.77        5.51
# Ox_out          4,8,2,1,1                       5.28        5.57
# Oy_out          4,8,2,1,1                       5.28        5.57
# ORx_out         3,4,1,2,6,6,2                  38.98        5.58
# ORy_out         4,8,2,2,6,6,3                  24.51        5.58
# ORJx_det_out    3,4,1,2,6,6,2                  38.98        5.59
# ORJy_det_out    4,8,2,2,6,6,3                  24.51        5.59
# Intg_bound_out  4,9,3,2                        85.47        5.76
# H_bound_out     4,9,3,3,3,2                  5258.22        5.77
# B_out           4,9,3,3,3,2                  5258.22        5.77
# Assembling Patch 6
# Step            Ranks                     Compression  Elapsed Time (s)
# J               3,9,12,4,4,4                    4.35        5.86
# J_det           3,9,3                           0.45        5.94
# R               3,9,23,9,3                      0.51        5.97
# dR              3,9,27,16,6,2                   0.60        5.97
# J_detRT         3,9,24,9,3                      0.49        5.98
# JdR             3,9,27,16,6,2                   0.60        5.99
# Intg_int        10                              1.25        6.24
# Intg_str        19,2                            0.87        6.24
# H               3,3,3,3,3,48                  664.69        6.24
# S               3,3,2,1,1,10              1676258.35        6.24
# F               1,1,1,1,1,10              2471724.14        6.24
# Jx_det_in       2,3                             0.58        6.32
# Jy_det_in       1,1                             2.25        6.32
# Rx_in           2,6,6,2                         0.85        6.32
# Ry_in           2,6,6,3                         0.77        6.32
# Ox_in           4,8,2,1,1                       5.28        6.32
# Oy_in           4,8,2,1,1                       5.28        6.32
# ORx_in          4,16,10,18,18,6,2               3.97        6.34
# ORy_in          4,8,2,2,6,6,3                  24.51        6.34
# ORJx_det_in     4,16,10,18,18,6,2               3.97        6.36
# ORJy_det_in     4,8,2,2,6,6,3                  24.51        6.36
# Intg_bound_in   4,12,16,12,3                 5976.65        6.61
# H_bound_in      4,10,12,12,12,3             38307.49        6.61
# B_in            4,10,12,12,12,3            575431.17        6.61
# Jx_det_out      2,3                             0.58        6.62
# Jy_det_out      1,1                             2.25        6.62
# Rx_out          2,6,6,2                         0.85        6.64
# Ry_out          2,6,6,3                         0.77        6.64
# Ox_out          4,8,2,1,1                       5.28        6.69
# Oy_out          4,8,2,1,1                       5.28        6.69
# ORx_out         4,16,10,18,18,6,2               3.97        6.71
# ORy_out         4,8,2,2,6,6,3                  24.51        6.71
# ORJx_det_out    4,16,10,18,18,6,2               3.97        6.73
# ORJy_det_out    4,8,2,2,6,6,3                  24.51        6.73
# Intg_bound_out  4,10,12,3                      24.52        6.97
# H_bound_out     4,10,12,12,12,3               769.41        6.97
# B_out           4,10,12,12,12,3               769.41        6.97
# Assembling Patch 7
# Step            Ranks                     Compression  Elapsed Time (s)
# J               3,9,6,4,4,4                     6.69        7.06
# J_det           3,6,3                           0.64        7.15
# R               3,9,9,9,3                       1.09        7.18
# dR              3,9,15,12,5,2                   1.17        7.18
# J_detRT         3,9,9,9,3                       1.09        7.18
# JdR             3,9,15,16,6,2                   0.94        7.19
# Intg_int        1                              12.50        7.39
# Intg_str        4,2                             4.11        7.39
# H               3,3,3,3,3,9                  2909.09        7.39
# S               3,3,2,1,1,1               3360000.00        7.39
# F               1,1,1,1,1,1               9467169.81        7.39
# Jx_det_in       1,3                             0.90        7.47
# Jy_det_in       1,1                             2.25        7.47
# Rx_in           2,6,6,2                         0.85        7.47
# Ry_in           2,6,6,3                         0.77        7.47
# Ox_in           2,2,2,1,1                      23.04        7.47
# Oy_in           2,2,2,1,1                      23.04        7.47
# ORx_in          4,16,18,18,18,6,2               3.04        7.49
# ORy_in          2,2,2,2,6,6,3                  40.66        7.49
# ORJx_det_in     4,16,18,18,18,6,2               3.04        7.51
# ORJy_det_in     2,2,2,2,6,6,3                  40.66        7.51
# Intg_bound_in   4,8,14,20,3                  5445.52        7.81
# H_bound_in      4,8,13,13,20,3              23567.13        7.82
# B_in            4,8,13,13,20,3             364651.16        7.82
# Jx_det_out      1,3                             0.90        7.83
# Jy_det_out      1,1                             2.25        7.83
# Rx_out          2,6,6,2                         0.85        7.84
# Ry_out          2,6,6,3                         0.77        7.84
# Ox_out          2,2,2,1,1                      23.04        7.90
# Oy_out          2,2,2,1,1                      23.04        7.90
# ORx_out         4,16,18,18,18,6,2               3.04        7.92
# ORy_out         2,2,2,2,6,6,3                  40.66        7.92
# ORJx_det_out    4,16,18,18,18,6,2               3.04        7.93
# ORJy_det_out    2,2,2,2,6,6,3                  40.66        7.93
# Intg_bound_out  4,8,13,3                       24.84        8.24
# H_bound_out     4,8,13,13,13,3                696.95        8.24
# B_out           4,8,13,13,13,3                696.95        8.24
# Assembling Patch 8
# Step            Ranks                     Compression  Elapsed Time (s)
# J               3,9,10,4,4,4                    4.93        8.33
# J_det           3,9,3                           0.45        8.42
# R               3,9,23,9,3                      0.51        8.45
# dR              3,9,27,16,6,2                   0.60        8.45
# J_detRT         3,9,24,9,3                      0.49        8.45
# JdR             3,9,27,16,6,2                   0.60        8.46
# Intg_int        10                              1.25        8.70
# Intg_str        19,2                            0.87        8.70
# H               3,3,3,3,3,48                  664.69        8.70
# S               3,3,2,1,1,10              1676258.35        8.70
# F               1,1,1,1,1,1               9467169.81        8.71
# Jx_det_in       1,3                             0.90        8.79
# Jy_det_in       1,1                             2.25        8.79
# Rx_in           1,3,3,1                         3.24        8.79
# Ry_in           2,6,6,3                         0.77        8.79
# Ox_in           4,8,2,1,1                       5.28        8.79
# Oy_in           4,8,2,1,1                       5.28        8.79
# ORx_in          3,12,9,9,9,3,1                  9.55        8.80
# ORy_in          4,8,2,2,6,6,3                  24.51        8.80
# ORJx_det_in     3,12,9,9,9,3,1                  9.55        8.82
# ORJy_det_in     4,8,2,2,6,6,3                  24.51        8.82
# Intg_bound_in   3,9,13,11,2                  9201.28        9.02
# H_bound_in      4,10,11,11,11,2             45860.99        9.03
# B_in            4,10,11,11,11,2            683777.87        9.03
# Jx_det_out      1,3                             0.90        9.04
# Jy_det_out      1,1                             2.25        9.04
# Rx_out          2,6,6,2                         0.85        9.05
# Ry_out          2,6,6,3                         0.77        9.05
# Ox_out          4,8,2,1,1                       5.28        9.11
# Oy_out          4,8,2,1,1                       5.28        9.11
# ORx_out         3,12,9,18,18,6,2                4.61        9.12
# ORy_out         4,8,2,2,6,6,3                  24.51        9.12
# ORJx_det_out    3,12,9,18,18,6,2                4.61        9.14
# ORJy_det_out    4,8,2,2,6,6,3                  24.51        9.14
# Intg_bound_out  4,10,11,2                      32.89        9.35
# H_bound_out     4,10,11,11,11,2               955.90        9.35
# B_out           4,10,11,11,11,2               955.90        9.35
# Assembling Patch 9
# Step            Ranks                     Compression  Elapsed Time (s)
# J               2,6,3,3,3,3                    15.43        9.44
# J_det           1,2,1                           4.50        9.52
# R               3,9,9,9,3                       1.09        9.55
# dR              3,8,12,12,5,2                   1.44        9.55
# J_detRT         3,9,9,9,3                       1.09        9.56
# JdR             3,9,15,14,6,2                   1.03        9.57
# Intg_int        1                              12.50        9.73
# Intg_str        3,2                             5.46        9.73
# H               3,3,3,3,3,7                  3518.32        9.73
# S               3,3,2,1,1,1               3360000.00        9.73
# F               1,1,1,1,1,1               9467169.81        9.73
# Jx_det_in       1,1                             2.25        9.82
# Jy_det_in       1,1                             2.25        9.82
# Rx_in           1,3,3,1                         3.24        9.82
# Ry_in           2,6,6,3                         0.77        9.82
# Ox_in           4,5,2,1,1                       7.89        9.82
# Oy_in           4,5,2,1,1                       7.89        9.82
# ORx_in          3,4,1,1,3,3,1                  82.29        9.83
# ORy_in          4,5,2,2,6,6,3                  29.54        9.83
# ORJx_det_in     3,4,1,1,3,3,1                  82.29        9.84
# ORJy_det_in     4,5,2,2,6,6,3                  29.54        9.84
# Intg_bound_in   3,7,8,3,2                   17888.20       10.04
# H_bound_in      5,8,3,3,3,2                496682.80       10.04
# B_in            5,8,3,3,3,2               5939940.81       10.04
# Jx_det_out      1,1                             2.25       10.05
# Jy_det_out      1,1                             2.25       10.05
# Rx_out          2,6,6,2                         0.85       10.07
# Ry_out          2,6,6,3                         0.77       10.07
# Ox_out          4,5,2,1,1                       7.89       10.12
# Oy_out          4,5,2,1,1                       7.89       10.12
# ORx_out         3,4,1,2,6,6,2                  38.98       10.14
# ORy_out         4,5,2,2,6,6,3                  29.54       10.14
# ORJx_det_out    3,4,1,2,6,6,2                  38.98       10.15
# ORJy_det_out    4,5,2,2,6,6,3                  29.54       10.15
# Intg_bound_out  4,8,3,2                        90.91       10.33
# H_bound_out     4,8,3,3,3,2                  5499.18       10.33
# B_out           4,8,3,3,3,2                  5499.18       10.33
# Assembling Patch 10
# Step            Ranks                     Compression  Elapsed Time (s)
# J               3,9,12,4,4,4                    4.35       10.42
# J_det           3,9,3                           0.45       10.51
# R               3,9,23,9,3                      0.51       10.53
# dR              3,9,27,16,6,2                   0.60       10.53
# J_detRT         3,9,27,9,3                      0.45       10.54
# JdR             3,9,27,16,6,2                   0.60       10.55
# Intg_int        17                              0.74       10.79
# Intg_str        19,2                            0.87       10.79
# H               3,3,3,3,3,55                  583.84       10.79
# S               3,3,2,1,1,17              1206153.85       10.79
# F               1,1,1,1,1,17              1569635.04       10.80
# Jx_det_in       2,3                             0.58       10.88
# Jy_det_in       1,1                             2.25       10.88
# Rx_in           2,6,6,2                         0.85       10.88
# Ry_in           2,6,6,3                         0.77       10.88
# Ox_in           4,5,2,1,1                       7.89       10.88
# Oy_in           4,5,2,1,1                       7.89       10.88
# ORx_in          4,16,10,18,18,6,2               3.97       10.89
# ORy_in          4,5,2,2,6,6,3                  29.54       10.89
# ORJx_det_in     4,16,10,18,18,6,2               3.97       10.91
# ORJy_det_in     4,5,2,2,6,6,3                  29.54       10.91
# Intg_bound_in   4,10,14,12,3                 6730.94       11.16
# H_bound_in      5,11,12,12,12,3             38146.98       11.17
# B_in            5,11,12,12,12,3            567334.40       11.17
# Jx_det_out      2,3                             0.58       11.18
# Jy_det_out      1,1                             2.25       11.18
# Rx_out          2,6,6,2                         0.85       11.19
# Ry_out          2,6,6,3                         0.77       11.19
# Ox_out          4,5,2,1,1                       7.89       11.25
# Oy_out          4,5,2,1,1                       7.89       11.25
# ORx_out         4,16,10,18,18,6,2               3.97       11.26
# ORy_out         4,5,2,2,6,6,3                  29.54       11.26
# ORJx_det_out    4,16,10,18,18,6,2               3.97       11.28
# ORJy_det_out    4,5,2,2,6,6,3                  29.54       11.28
# Intg_bound_out  4,10,12,3                      24.52       11.52
# H_bound_out     4,10,12,12,12,3               769.41       11.52
# B_out           4,10,12,12,12,3               769.41       11.52
# Assembling Patch 11
# Step            Ranks                     Compression  Elapsed Time (s)
# J               3,9,12,4,4,4                    4.35       11.61
# J_det           3,6,3                           0.64       11.69
# R               3,9,9,9,3                       1.09       11.72
# dR              3,9,15,12,5,2                   1.17       11.72
# J_detRT         3,9,18,9,3                      0.63       11.73
# JdR             3,9,27,16,6,2                   0.60       11.74
# Intg_int        2                               6.25       11.93
# Intg_str        4,2                             4.11       11.93
# H               3,3,3,3,3,10                 2677.29       11.93
# S               3,3,2,1,1,2               3022650.60       11.93
# F               1,1,1,1,1,1               9467169.81       11.93
# Jx_det_in       2,3                             0.58       12.01
# Jy_det_in       1,1                             2.25       12.01
# Rx_in           2,6,6,2                         0.85       12.01
# Ry_in           2,6,6,3                         0.77       12.01
# Ox_in           2,2,2,1,1                      23.04       12.01
# Oy_in           2,2,2,1,1                      23.04       12.01
# ORx_in          4,16,18,18,18,6,2               3.04       12.03
# ORy_in          2,2,2,2,6,6,3                  40.66       12.03
# ORJx_det_in     4,16,18,18,18,6,2               3.04       12.04
# ORJy_det_in     2,2,2,2,6,6,3                  40.66       12.04
# Intg_bound_in   4,8,14,20,3                  5445.52       12.36
# H_bound_in      5,9,18,18,20,3              16082.28       12.37
# B_in            5,9,18,18,20,3             248522.49       12.37
# Jx_det_out      2,3                             0.58       12.37
# Jy_det_out      1,1                             2.25       12.37
# Rx_out          2,6,6,2                         0.85       12.39
# Ry_out          2,6,6,3                         0.77       12.39
# Ox_out          2,2,2,1,1                      23.04       12.44
# Oy_out          2,2,2,1,1                      23.04       12.44
# ORx_out         4,16,18,18,18,6,2               3.04       12.46
# ORy_out         2,2,2,2,6,6,3                  40.66       12.46
# ORJx_det_out    4,16,18,18,18,6,2               3.04       12.48
# ORJy_det_out    2,2,2,2,6,6,3                  40.66       12.48
# Intg_bound_out  4,8,18,3                       18.65       12.78
# H_bound_out     4,8,18,18,18,3                404.77       12.78
# B_out           4,8,18,18,18,3                404.77       12.78
# Assembling Patch 12
# Step            Ranks                     Compression  Elapsed Time (s)
# J               3,9,12,4,4,4                    4.35       12.87
# J_det           3,9,3                           0.45       12.95
# R               3,9,23,9,3                      0.51       12.98
# dR              3,9,27,16,6,2                   0.60       12.98
# J_detRT         3,9,27,9,3                      0.45       12.99
# JdR             3,9,27,16,6,2                   0.60       13.00
# Intg_int        16                              0.78       13.26
# Intg_str        19,2                            0.87       13.26
# H               3,3,3,3,3,54                  594.16       13.26
# S               3,3,2,1,1,16              1256494.16       13.26
# F               1,1,1,1,1,1               9467169.81       13.26
# Jx_det_in       2,3                             0.58       13.35
# Jy_det_in       1,1                             2.25       13.35
# Rx_in           2,6,6,2                         0.85       13.35
# Ry_in           2,6,6,3                         0.77       13.35
# Ox_in           4,5,2,1,1                       7.89       13.35
# Oy_in           4,5,2,1,1                       7.89       13.35
# ORx_in          4,13,10,18,18,6,2               4.25       13.36
# ORy_in          4,5,2,2,6,6,3                  29.54       13.36
# ORJx_det_in     4,13,10,18,18,6,2               4.25       13.38
# ORJy_det_in     4,5,2,2,6,6,3                  29.54       13.38
# Intg_bound_in   3,8,11,12,3                  8625.98       13.65
# H_bound_in      6,9,12,12,12,3              38255.57       13.65
# B_in            6,9,12,12,12,3             574260.37       13.65
# Jx_det_out      2,3                             0.58       13.66
# Jy_det_out      1,1                             2.25       13.66
# Rx_out          2,6,6,2                         0.85       13.68
# Ry_out          2,6,6,3                         0.77       13.68
# Ox_out          4,5,2,1,1                       7.89       13.73
# Oy_out          4,5,2,1,1                       7.89       13.73
# ORx_out         4,13,10,18,18,6,2               4.25       13.75
# ORy_out         4,5,2,2,6,6,3                  29.54       13.75
# ORJx_det_out    4,13,10,18,18,6,2               4.25       13.76
# ORJy_det_out    4,5,2,2,6,6,3                  29.54       13.76
# Intg_bound_out  4,8,12,3                       26.61       14.00
# H_bound_out     4,8,12,12,12,3                792.64       14.00
# B_out           4,8,12,12,12,3                792.64       14.00
#
# Final Operators
# H               3,3,3,6,24,19              533960.80       14.15
# S               3,3,2,4,10,18             1585896.40       14.15
# F               1,1,1,2,4,17              5277055.21       14.15
# B_in            8,14,30,30,25,4            110587.49       14.15
# B_out           4,10,26,26,22,3            147962.09       14.15

# %%
k, psi = eig(
    LHS=LinearOperator([H_tt, B_out_m - B_in_m, -S_tt], N=assembler.N, M=assembler.M),
    RHS=LinearOperator([F_tt], N=assembler.N, M=assembler.M),
    tols=1e-8,
    max_iters=500,
    device=1,
    linear_solver_opts={
        "max_iterations": 150,
        "threshold": 1e-10,
        "resets": 50,
    },
)

# Compute scalar flux
phi = assembler.angular_integral(psi).numpy().reshape(
    (xs_server.num_groups, mesh.num_patches, -1)
)
# Out:
# Starting power iteration
# -- (0): k = 0.83031512, Angular Flux L2-Error = 3.57279735, Elapsed Time = 36.845
# -- (1): k = 0.83225293, Angular Flux L2-Error = 0.00356892, Elapsed Time = 73.83
# -- (2): k = 0.83224821, Angular Flux L2-Error = 2.046e-05, Elapsed Time = 110.794
# -- (3): k = 0.83224809, Angular Flux L2-Error = 2.2e-07, Elapsed Time = 148.749
# -- (4): k = 0.83224809, Angular Flux L2-Error = 0.0, Elapsed Time = 175.257
# -- Converged: k = 0.83224809, Elapsed Time = 175.257

# %%
# Get OpenMC solution
k_mc = [0.83942, 0.00006]
phi_mc = np.load("./openmc/openmc_ba/data/mesh_flux.npy")

# Ensure OpenMC solution is normalized
phi_mc /= np.linalg.norm(phi_mc.flatten(), 2)

# Calculate eigenvalue error
print("keff error: {} +/- {} pcm".format((k - k_mc[0]) * 1e5, k_mc[1]))
# Out:
# keff error: -717.1914685668246 +/- 6e-05 pcm

# %%
# Map rectangular mesh
pids, coords = mesh.map_regular_mesh(shape=phi_mc.shape[1:], N=(2, 2))

# Iterate through groups and plot
phi_avg = np.zeros(phi_mc.shape)
for g in range(xs_server.num_groups):
    # Set control points
    mesh.set_phi(phi[g,])

    # Calculate regular mesh
    phi_avg[g,] = mesh.regular_mesh(pids, coords)

    # Plot
    plt.clf()
    ax, cbar = mesh.plot(num_nodes=128, plot_ctrlpts=False)
    cbar.set_label(f"$\\phi_{g + 1}" + "(\\hat{x}, \\hat{y})$")
    plt.tight_layout()
    plt.savefig(f"./figs/phi_ba{g + 1}.png", dpi=300)
    plt.show()

# %%
# Normalize average
phi_avg /= np.linalg.norm(phi_avg.flatten(), 2)

# Regular mesh
X, Y = np.meshgrid(
    np.linspace(0, X / 2, phi_mc.shape[1]),
    np.linspace(0, X / 2, phi_mc.shape[2]),
)

for g in range(xs_server.num_groups):    
    # Plot relative error
    plt.clf()
    cmesh = plt.pcolormesh(
        X, Y, (phi_mc[g,] - phi_avg[g,]) / phi_mc[g,], cmap="plasma"
    )
    plt.colorbar(
        cmesh, 
        label=f"Relative Scalar Flux Error ($g = {g + 1}$)",
    )
    plt.xlabel(r"$x(\hat{x}, \hat{y})~(cm)$")
    plt.ylabel(r"$y(\hat{x}, \hat{y})~(cm)$")
    plt.tight_layout()
    plt.savefig(f"./figs/phi_ba{g + 1}_error.png", dpi=300)
    plt.show()
    
    # Calculate groups L2-error
    print(
        "Scalar flux Relative L2-error (g = {}): {}".format(
            g + 1, 
            np.linalg.norm(
                (phi_avg[g,] - phi_mc[g,]).flatten(), 2
            ) / np.linalg.norm(phi_mc[g,].flatten(), 2)
        )
    )
print(
    "Total scalar flux Relative L2-error: {}".format(
        np.linalg.norm(
            (phi_avg - phi_mc).flatten(), 2
        ) / np.linalg.norm(phi_mc.flatten(), 2)
    )
)
# Out:
# Scalar flux Relative L2-error (g = 1): 0.021208478992245282
# Scalar flux Relative L2-error (g = 2): 0.00763504274419315
# Scalar flux Relative L2-error (g = 3): 0.0053400617615118875
# Scalar flux Relative L2-error (g = 4): 0.004970455377373358
# Scalar flux Relative L2-error (g = 5): 0.012923898665619651
# Scalar flux Relative L2-error (g = 6): 0.026412706154015662
# Scalar flux Relative L2-error (g = 7): 0.028312835353760824
# Total scalar flux Relative L2-error: 0.010630211605353856
